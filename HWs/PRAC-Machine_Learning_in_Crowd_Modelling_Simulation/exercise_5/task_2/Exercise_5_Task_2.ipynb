# %%
from linear_solver import LinearSolver
from trajectory import Trajectory

# %%
solver = LinearSolver(file_name_x0="linear_vectorfield_data_x0.txt", file_name_x1="linear_vectorfield_data_x1.txt", folder_path='input')
A = solver.solve_linear()
# Out:
# loss: 9.46778204840306e-09

# %%
trajectory = Trajectory(A)
trajectory.plot_trajectory()
