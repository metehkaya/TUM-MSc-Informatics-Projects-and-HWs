# %%
from linear_solver import LinearSolver
from nonlinear_solver import NonlinearSolver

# %%
solver = LinearSolver(file_name="linear_function_data.txt", folder_path='input')
solver.solve_linear()
# Out:
# m: 0.7500002401387144 and c: 0.0
# loss: 1.0611679491268278e-10

# %%
solver = LinearSolver(file_name="nonlinear_function_data.txt", folder_path='input')
solver.solve_linear()
# Out:
# m: 0.03321036077812005 and c: 0.0
# loss: 0.7748919879012244

# %%
L, eps = (20, .94)
solver = NonlinearSolver(L=L, eps=eps, file_name="nonlinear_function_data.txt", folder_path='input')
solver.solve_nonlinear()
# Out:
# loss: 2.2325179650468177e-10
